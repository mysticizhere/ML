# %% [markdown]
# <a href="https://colab.research.google.com/github/mysticizhere/ML/blob/main/openCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv

# %%
from google.colab.patches import cv2_imshow

# %%
# !wget https://www.gardendesign.com/pictures/images/675x529Max/site_3/helianthus-yellow-flower-pixabay_11863.jpg
# Out:
# --2022-08-29 10:30:54--  https://www.gardendesign.com/pictures/images/675x529Max/site_3/helianthus-yellow-flower-pixabay_11863.jpg
# Resolving www.gardendesign.com (www.gardendesign.com)... 104.26.15.221, 172.67.74.247, 104.26.14.221
# Connecting to www.gardendesign.com (www.gardendesign.com)|104.26.15.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69054 (67K) [image/jpeg]
# Saving to: ‘helianthus-yellow-flower-pixabay_11863.jpg’
#
# helianthus-yellow-f 100%[===================>]  67.44K  --.-KB/s    in 0.001s
#
# 2022-08-29 10:30:54 (51.4 MB/s) - ‘helianthus-yellow-flower-pixabay_11863.jpg’ saved [69054/69054]

# %%
# !mv helianthus* test_image.jpg

# %%
img = cv.imread('test_image.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=675x450 at 0x7FA77260F690>

# %%
def rescaleFrame(frame, scale=0.75):
  width = int(frame.shape[1]*scale)
  height = int(frame.shape[0]*scale)
  dimensions = (width,height)

  return cv.resize(frame,dimensions,interpolation=cv.INTER_AREA)

# %%
img_rescale = rescaleFrame(img)

# %%
cv2_imshow(img_rescale)
# Out:
# <PIL.Image.Image image mode=RGB size=506x337 at 0x7FA771EFBA90>

# %%
img_rescale2 = rescaleFrame(img, 1.25)

# %%
cv2_imshow(img_rescale2)
# Out:
# <PIL.Image.Image image mode=RGB size=843x562 at 0x7FA771EFD110>

# %%
import numpy as np
